# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
# Out:
# 2026-01-15 18:33:27.314142: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768502007.539861      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768502007.603751      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768502008.137352      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
from tensorflow.keras.layers import Dense,Dropout

# %%
from tensorflow.keras.optimizers import Adam

# %%
def five_layer_nn(input_dim, hidden_dim, output_dim):
    model=Sequential([
        Dense(hidden_dim, activation='relu', input_shape=(input_dim,)),
        Dense(hidden_dim, activation='relu'),
        Dense(hidden_dim, activation='relu'),
        Dense(output_dim, activation='softmax')
    ])
    return model

# %%
input_dim = 100      # number of features
hidden_dim = 64
output_dim = 10      # number of classes

model = five_layer_nn(input_dim, hidden_dim, output_dim)

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',  # binary_crossentropy for binary
    metrics=['accuracy']
)

model.summary()
# Out:
# I0000 00:00:1768502713.236630      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1768502713.237333      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_15 (Dense)                │ (None, 64)             │         6,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 64)             │         4,160 │
# ...

# %%
import numpy as np

# %%
X_train = np.random.rand(1000, input_dim)

# %%
X_train.shape
# Out:
# (1000, 100)

# %%
print(X_train[0])
# Out:
# [0.50550411 0.43110566 0.9379144  0.78058719 0.5724518  0.62843502
#  0.11912056 0.09845913 0.27130422 0.92401016 0.53705524 0.31541607
#  0.79472112 0.70496413 0.37001446 0.30107492 0.75692944 0.2939991
#  0.33668606 0.52536752 0.83662346 0.6017739  0.42454618 0.08186469
#  0.6274396  0.06375997 0.49309689 0.62293118 0.33334273 0.15603829
#  0.6953939  0.47915266 0.16194524 0.56885118 0.93480201 0.80752042
#  0.92644218 0.53540458 0.52872664 0.66119364 0.32241878 0.63443202
#  0.53268229 0.65178013 0.359856   0.15547862 0.38616413 0.15608754
#  0.88602325 0.964975   0.54965054 0.09748714 0.25118949 0.92636208
#  0.75599084 0.31056145 0.22593746 0.0683352  0.90370894 0.36314554
#  0.5539992  0.06152627 0.13793719 0.54162909 0.71429528 0.53028676
#  0.84832318 0.09773416 0.956814   0.39266313 0.96348758 0.31341314
#  0.94409259 0.00210315 0.99868618 0.57472001 0.11177757 0.53778624
#  0.31817504 0.59059008 0.66939135 0.77780819 0.89476334 0.42310684
# ...

# %%
row_len=len(X_train[0])
print(row_len)
# Out:
# 100

# %%
col_len=len(X_train[:,0])
print(col_len)
# Out:
# 1000

# %%
y_train = tf.keras.utils.to_categorical(
    np.random.randint(0, output_dim, size=(1000,)),
    num_classes=output_dim
)

# %% [markdown]
# **Training**

# %%
history=model.fit(
    X_train,
    y_train, 
    epochs=20,
    b
)

# %%
# Example dummy data
import numpy as np

X_train = np.random.rand(1000, input_dim)

history = model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1187 - loss: 2.5952 - val_accuracy: 0.1050 - val_loss: 2.3746
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1403 - loss: 2.3049 - val_accuracy: 0.1200 - val_loss: 2.3316
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1349 - loss: 2.2737 - val_accuracy: 0.1050 - val_loss: 2.3376
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1826 - loss: 2.2502 - val_accuracy: 0.1100 - val_loss: 2.3436
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2149 - loss: 2.1988 - val_accuracy: 0.0900 - val_loss: 2.3608
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2134 - loss: 2.1926 - val_accuracy: 0.0850 - val_loss: 2.3878
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2103 - loss: 2.1712 - val_accuracy: 0.1000 - val_loss: 2.3772
# Epoch 8/100
# ...

# %%
loss, accuracy = model.evaluate(X_train, y_train)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9696 - loss: 0.3029
# Accuracy: 0.8210

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
print(history.history.keys())
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])
